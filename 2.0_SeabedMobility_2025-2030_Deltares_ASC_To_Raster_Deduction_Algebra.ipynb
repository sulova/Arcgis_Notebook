# %% [markdown]
# ## Seabed Mobility Assessment for Subsea Battery Placement
# ### 2nd Iteration: Seabed Mobility Analysis 2025-2030 by Deltares

# %%
import os
import arcpy
from arcpy.sa import *
import numpy as np
import matplotlib.pyplot as plt
from arcgis.gis import GIS
from arcgis import geometry
from arcgis import env
from arcgis.raster import ImageryLayer

# %% [markdown]
# ### 1) Find MAX and MIN across a set of raster

# %% [markdown]
# #### BEB Min and Max

# %%
# Set the DEDUCTION workspace to the folder containing your raster datasets
arcpy.env.workspace = r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Deduction"
rasters = arcpy.ListRasters()

# Set folder to SeabedMobility_Deltares_Max_Min_Final_2025_2030
output_folder = r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Max_Min_Final_2025_2030"


rasters_25_30_BEB = [rasters[0],rasters[2]]
rasters_25_30_BEB
# Out:
# ['Deduction_BEB_2025_BEB_2026.tif', 'Deduction_BEB_2025_BEB_2030.tif']

# %% [markdown]
# -  display a map with a raster file

# %%
output_max_raster = os.path.join(output_folder, "BEB_max_2025_2030_v0.tif")
raster_layer = Raster(output_max_raster)
raster_layer
# Out:
# \\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Max_Min_Final_2025_2030\BEB_max_2025_2030_v0.tif

# %% [markdown]
# ## BEB Min and Max

# %%
out_max_raster = arcpy.sa.CellStatistics(rasters_25_30_BEB, "MAXIMUM", "DATA")
out_min_raster = arcpy.sa.CellStatistics(rasters_25_30_BEB, "MINIMUM", "DATA")


# Define the output raster paths for maximum and minimum values
output_max_raster = os.path.join(output_folder, "BEB_max_2025_2030_v0.tif")
output_min_raster = os.path.join(output_folder, "BEB_min_2025_2030_v0.tif")

# Save the maximum and minimum value rasters
# out_max_raster.save(output_max_raster)
# out_min_raster.save(output_min_raster)

print(f"Maximum value raster saved to: {output_max_raster}")
print(f"Minimum value raster saved to: {output_min_raster}")


arcpy.env.workspace = r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Max_Min_Final_2025_2030\SeabedMobility_Deltares_Max_Min_Final_2025_2030.gdb"

# Use CopyRaster_management to save the raster to the geodatabase
arcpy.CopyRaster_management(output_max_raster, "BEB_max_2025_2030")
arcpy.CopyRaster_management(output_min_raster, "BEB_min_2025_2030")

# %% [markdown]
# ## HSBL Min and Max

# %%
# Set the DEDUCTION workspace to the folder containing your raster datasets
arcpy.env.workspace = r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Deduction"
rasters = arcpy.ListRasters()
rasters_HSBL = rasters[12:20]
rasters_25_30_HSBL = [rasters_HSBL[0],rasters_HSBL[1]]
rasters_25_30_HSBL
# Out:
# ['Deduction_HSBL_2025_HSBL_2026.tif', 'Deduction_HSBL_2025_HSBL_2030.tif']

# %%
out_max_raster = arcpy.sa.CellStatistics(rasters_25_30_HSBL, "MAXIMUM", "DATA")
out_min_raster = arcpy.sa.CellStatistics(rasters_25_30_HSBL, "MINIMUM", "DATA")

output_folder = r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Max_Min_Final_2025_2030"

# Define the output raster paths for maximum and minimum values
output_max_raster = os.path.join(output_folder, "HSBL_max_2025_2030_v0.tif")
output_min_raster = os.path.join(output_folder, "HSBL_min_2025_2030_v0.tif")

# Save the maximum and minimum value rasters
out_max_raster.save(output_max_raster)
out_min_raster.save(output_min_raster)

print(f"Maximum value raster saved to: {output_max_raster}")
print(f"Minimum value raster saved to: {output_min_raster}")


arcpy.env.workspace = r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Max_Min_Final_2025_2030\SeabedMobility_Deltares_Max_Min_Final_2025_2030.gdb"

# Use CopyRaster_management to save the raster to the geodatabase
arcpy.CopyRaster_management(output_max_raster, "HSBL_max_2025_2030")
arcpy.CopyRaster_management(output_min_raster, "HSBL_min_2025_2030")
# Out:
# Maximum value raster saved to: \\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Max_Min_Final_2025_2030\HSBL_max_2025_2030_v0.tif
# Minimum value raster saved to: \\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Max_Min_Final_2025_2030\HSBL_min_2025_2030_v0.tif
# <Result '\\\\WM20ocqu46ph01\\WF_Projects\\NL_HKW\\1_INPUT\\SITEINV\\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\\SeabedMobility_Deltares_Max_Min_Final_2025_2030\\SeabedMobility_Deltares_Max_Min_Final_2025_2030.gdb\\HSBL_min_2025_2030'>

# %% [markdown]
# ### LSBL Min and Max

# %%
# Set the DEDUCTION workspace to the folder containing your raster datasets
arcpy.env.workspace = r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Deduction"
rasters = arcpy.ListRasters()
rasters_LSBL = rasters[22:30]
rasters_25_30_LSBL = [rasters_LSBL[0],rasters_LSBL[1]]
rasters_25_30_LSBL
# Out:
# ['Deduction_LSBL_2025_LSBL_2026.tif', 'Deduction_LSBL_2025_LSBL_2030.tif']

# %%
out_max_raster = arcpy.sa.CellStatistics(rasters_25_30_LSBL, "MAXIMUM", "DATA")
out_min_raster = arcpy.sa.CellStatistics(rasters_25_30_LSBL, "MINIMUM", "DATA")

output_folder = r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Max_Min_Final_2025_2030"

# Define the output raster paths for maximum and minimum values
output_max_raster = os.path.join(output_folder, "LSBL_max_2025_2030_v0.tif")
output_min_raster = os.path.join(output_folder, "LSBL_min_2025_2030_v0.tif")

# Save the maximum and minimum value rasters
out_max_raster.save(output_max_raster)
out_min_raster.save(output_min_raster)

print(f"Maximum value raster saved to: {output_max_raster}")
print(f"Minimum value raster saved to: {output_min_raster}")


arcpy.env.workspace = r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Max_Min_Final_2025_2030\SeabedMobility_Deltares_Max_Min_Final_2025_2030.gdb"

# Use CopyRaster_management to save the raster to the geodatabase
arcpy.CopyRaster_management(output_max_raster, "LSBL_max_2025_2030")
arcpy.CopyRaster_management(output_min_raster, "LSBL_min_2025_2030")
# Out:
# Maximum value raster saved to: \\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Max_Min_Final_2025_2030\LSBL_max_2025_2030_v0.tif
# Minimum value raster saved to: \\WM20ocqu46ph01\WF_Projects\NL_HKW\1_INPUT\SITEINV\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\SeabedMobility_Deltares_Max_Min_Final_2025_2030\LSBL_min_2025_2030_v0.tif
# <Result '\\\\WM20ocqu46ph01\\WF_Projects\\NL_HKW\\1_INPUT\\SITEINV\\20230928_Deltares_Seabed_Mobility_Pooyan_Ghasemi_Ecodoc004813220-02\\SeabedMobility_Deltares_Max_Min_Final_2025_2030\\SeabedMobility_Deltares_Max_Min_Final_2025_2030.gdb\\LSBL_min_2025_2030'>

# %% [markdown]
# ### Metadata
#
# -Copy raster to GDB

# %%
list_shp = [r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\2_FINAL\SITEINV\SITEINV.gdb\HKW_VII_Seabed_Mobility_HSBL_2025_2030_max_Deltares_UTM_v0",
            r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\2_FINAL\SITEINV\SITEINV.gdb\HKW_VII_Seabed_Mobility_HSBL_2025_2030_min_Deltares_UTM_v0",
            r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\2_FINAL\SITEINV\SITEINV.gdb\HKW_VII_Seabed_Mobility_HSBL_2025_2030_min_Deltares_UTM_v0",
            r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\2_FINAL\SITEINV\SITEINV.gdb\HKW_VII_Seabed_Mobility_HSBL_2025_2030_min_Deltares_UTM_v0",
            r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\2_FINAL\SITEINV\SITEINV.gdb\HKW_VII_Seabed_Mobility_HSBL_2025_2030_min_Deltares_UTM_v0",
            r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\2_FINAL\SITEINV\SITEINV.gdb\HKW_VII_Seabed_Mobility_HSBL_2025_2030_min_Deltares_UTM_v0"          
            
            
            ]

# %% [markdown]
# ## Delete

# %%
# Set the workspace (geodatabase path)
workspace = r"\\WM20ocqu46ph01\WF_Projects\NL_HKW\2_FINAL\SITEINV\SITEINV.gdb"

# Set the name of the raster dataset to delete
raster_name = "HKW_VII_Seabed_Mobility_BEB_max_Deltares_UTM_v1"

try:
    # Delete the raster dataset
    arcpy.Delete_management(os.path.join(workspace, raster_name))
    print(f"Raster dataset {raster_name} deleted successfully.")
except arcpy.ExecuteError:
    print(arcpy.GetMessages(2))
except Exception as e:
    print(e)
